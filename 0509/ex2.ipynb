# %%
from soynlp import DoublespaceLineCorpus
from soynlp.word import WordExtractor

# %%
all_data=DoublespaceLineCorpus('data1.txt',iter_sent=True)#문장으로 처리해서 가지고오게해줌
len(all_data)#문단이 아닌 문장으로 불러옴
# Out:
# 223357

# %%
n=0
for i in all_data:
    print(i)
    n+=1
    if n == 5:
        break
# Out:
# 19
# 1990
# 52 1 22
# 오패산터널 총격전 용의자 검거 서울 연합뉴스 경찰 관계자들이 19일 오후 서울 강북구 오패산 터널 인근에서 사제 총기를 발사해 경찰을 살해한 용의자 성모씨를 검거하고 있다 성씨는 검거 당시 서바이벌 게임에서 쓰는 방탄조끼에 헬멧까지 착용한 상태였다 독자제공 영상 캡처 연합뉴스
# 서울 연합뉴스 김은경 기자 사제 총기로 경찰을 살해한 범인 성모 46 씨는 주도면밀했다

# %%
m=WordExtractor()
m.train(all_data)
# Out:
# training was done. used memory 0.772 Gbse memory 0.839 Gb

# %%
m.extract()
# Out:
# all cohesion probabilities was computed. # words = 223348
# all branching entropies was computed # words = 360721
# all accessor variety was computed # words = 360721
# {'상': Scores(cohesion_forward=0, cohesion_backward=0, left_branching_entropy=4.89662658465921, right_branching_entropy=4.608860068057678, left_accessor_variety=484, right_accessor_variety=528, leftside_frequency=22847, rightside_frequency=12918),
#  '슴': Scores(cohesion_forward=0, cohesion_backward=0, left_branching_entropy=0.6365141682948128, right_branching_entropy=2.6173540473611863, left_accessor_variety=2, right_accessor_variety=20, leftside_frequency=11, rightside_frequency=132),
#  '옮': Scores(cohesion_forward=0, cohesion_backward=0, left_branching_entropy=1.7859499499009999, right_branching_entropy=1.3610171742564012, left_accessor_variety=28, right_accessor_variety=6, leftside_frequency=692, rightside_frequency=0),
# ...

# %%
t1 = '영화가 너무 웃겨'
t2 = '영화가 너무 웃겨 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'
t3 = '영화가 너무 웃겨 ㅋㅋ'
t4 = '영화가 너무 웃겨 ㅋㅋㅋ'

# %%
from soynlp.normalizer import *

# %%
emoticon_normalize(t1)
# Out:
# '영화가 너무 웃겨'

# %%
emoticon_normalize(t2)
# Out:
# '영화가 너무 웃겨 ㅋㅋ'

# %%
emoticon_normalize(t2,num_repeats=1)
# Out:
# '영화가 너무 웃겨 ㅋ'

# %%
t_e = '후후후후후후후훗'
emoticon_normalize(t_e)
# Out:
# '후후훗'
