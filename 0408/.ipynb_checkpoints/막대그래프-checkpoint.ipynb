# %% [markdown]
# ## 막대그래프

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']='Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus']=False#음수값지정
단어=['좋아','싫어','부정','긍정']
회수=[10,100,1,20]
plt.bar(단어,회수,color=['r','g','b','c'],alpha=0.5,width=0.5)
plt.plot(회수,'b--')
plt.ylim(1,110)
# Out:
# (1.0, 110.0)

# %%
단어=['좋아','싫어','부정','긍정']
회수=[10,100,1,20]
plt.bar(단어,회수)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
# Out:
# (array([  0.,  20.,  40.,  60.,  80., 100., 120.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
import numpy as np
단어=['좋아','싫어','부정','긍정']
회수=[10,100,5,20]
d=np.arange(4)
plt.barh(d,단어)
plt.yticks(d,단어)
# Out:
# ([<matplotlib.axis.YTick at 0x1da229768b0>,
#   <matplotlib.axis.YTick at 0x1da22976160>,
#   <matplotlib.axis.YTick at 0x1da2296e0a0>,
#   <matplotlib.axis.YTick at 0x1da229a0c70>],
#  [Text(0, 0, '좋아'), Text(0, 1, '싫어'), Text(0, 2, '부정'), Text(0, 3, '긍정')])

# %%
b=plt.barh(단어,회수)
for i in enumerate(b):
    print(i)
# Out:
# (0, <matplotlib.patches.Rectangle object at 0x000001DA2144B490>)
# (1, <matplotlib.patches.Rectangle object at 0x000001DA2151AEB0>)
# (2, <matplotlib.patches.Rectangle object at 0x000001DA2143C0D0>)
# (3, <matplotlib.patches.Rectangle object at 0x000001DA2143C820>)

# %%
b=plt.barh(단어,회수)
for i,d in enumerate(b):
    plt.text(d.get_height(),i,회수[i])

# %%
b2=plt.bar(단어,회수)
for i,d in enumerate(b):
    plt.text(i,d.get_height()+1,회수[i])

# %%
x=np.random.rand(100)
y=np.random.rand(100)
#plt.scatter(x축,y축)
plt.scatter(x,y,c='r',marker='*')

# %%
d1=np.random.rand(100,2)
d2=np.random.rand(100,2)
#plt.scatter(x축,y축)
plt.scatter(d1[:,0],d1[:,1],c='r',marker='*')
plt.scatter(d2[:,0],d1[:,1],c='b',marker='o')

# %%
단어=['좋아','싫어','부정','긍정']
x=np.arange(0,8,2)
A_횟수=[10,100,5,20]
B_횟수=[100,20,10,30]
C_횟수=[90,20,50,100]
plt.bar(x+0.00,A_횟수,width=0.5)
plt.bar(x+0.50,B_횟수,width=0.5)
plt.bar(x+1.00,C_횟수,width=0.5)
plt.xticks(x+0.5,단어)
# Out:
# ([<matplotlib.axis.XTick at 0x1da22879fa0>,
#   <matplotlib.axis.XTick at 0x1da22879850>,
#   <matplotlib.axis.XTick at 0x1da2147a4c0>,
#   <matplotlib.axis.XTick at 0x1da2130b220>],
#  [Text(0.5, 0, '좋아'),
#   Text(2.5, 0, '싫어'),
#   Text(4.5, 0, '부정'),
#   Text(6.5, 0, '긍정')])

# %%
x=['득표율']
y1=[10]
y2=[20]
y3=[30]
l_d=[40]
plt.bar(x,l_d)
plt.bar(x,y3,bottom=l_d)
plt.bar(x,y2,bottom=y3[0]+l_d[0])
plt.bar(x,y1,bottom=y2[0]+y3[0]+l_d[0])
# Out:
# <BarContainer object of 1 artists>

# %%
단어=['좋아_data','싫어_data','부정_data','긍정_data']
A_횟수=np.array([10,100,5,20])
B_횟수=np.array([100,20,10,30])
C_횟수=np.array([90,20,50,100])
plt.bar(단어,A_횟수,label='A')
plt.bar(단어,B_횟수,bottom=A_횟수,label='B')
plt.bar(단어,C_횟수,bottom=A_횟수+B_횟수,label='C')
plt.xticks(rotation=45)
plt.legend()

# %%
n=10000
X=np.random.normal(size=n)
plt.hist(X,bins=100)
plt.show()
